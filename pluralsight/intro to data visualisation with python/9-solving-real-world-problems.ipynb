# %% [markdown]
# #### What is the richest country in the world on a per-person basis?

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
# My try! - there are multiple rows/entries for each country-year. 
# I didn't take into account mean or latest values
data.sort_values('gdpPerCapita', ascending = False).iloc[0].country
# Out:
# 'Kuwait'

# %%
# Course - group by country and mean
mean_gdppercapita = data.groupby(['country']).mean().gdpPerCapita
mean_gdppercapita.head()
# Out:
# country
# Afghanistan     802.674598
# Albania        3255.366633
# Algeria        4426.025973
# Angola         3607.100529
# Argentina      8955.553783
# Name: gdpPerCapita, dtype: float64

# %%
# gdp per capita
top5 = mean_gdppercapita.sort_values(ascending=False).head()
top5
# Out:
# country
# Kuwait           65332.910472
# Switzerland      27074.334405
# Norway           26747.306554
# United States    26261.151347
# Canada           22410.746340
# Name: gdpPerCapita, dtype: float64

# %%
kuwait = data[data.country == 'Kuwait']
plt.plot(kuwait.year, kuwait.gdpPerCapita)
plt.title('GDP Per Capita in Kuwait')
plt.show()
# We can see Kuwait gdp per capita was large then dropped

# %%
plt.subplot(311)
plt.title('GDP Per Capita')
plt.plot(kuwait.year, kuwait.gdpPerCapita)

plt.subplot(312)
plt.title('GDP in Billions')
plt.plot(kuwait.year, kuwait.population * kuwait.gdpPerCapita /10**9)

plt.subplot(313)
plt.title('Population in Millions')
plt.plot(kuwait.year, kuwait.population /10**6)

plt.tight_layout()
plt.show()

# %%
plt.plot(kuwait.year, kuwait.population / kuwait.population.iloc[0] * 100)

kuwait_gdp = kuwait.population * kuwait.gdpPerCapita
plt.plot(kuwait.year, kuwait_gdp / kuwait_gdp.iloc[0] * 100)
plt.plot(kuwait.year, kuwait.gdpPerCapita / kuwait.gdpPerCapita.iloc[0] * 100)
plt.title('GDP and Population Growth in Kuwait (first year = 100)')
plt.legend(['Population', 'GDP', 'GDP Per Capita'])
plt.show()

# %%
us = data[data.country == 'United States']
plt.plot(us.year, us.gdpPerCapita)
plt.plot(kuwait.year, kuwait.gdpPerCapita)
plt.legend(['United States', 'Kuwait'])
plt.show()

# %% [markdown]
# ### Second Attempt
# Let's look at latest gdp per capita values

# %%
# Me, get the latest year for each country
max_year_by_country = data.groupby(['country'])['year'].transform('max')
data_latest_country = data[ data['year'] == max_year_by_country ]
max_gdppercapita = data_latest_country.sort_values('gdpPerCapita', ascending = False)
max_gdppercapita.iloc[0]. country
# Out:
# 'Norway'

# %%
top10_gdppercapita = max_gdppercapita.head(10)
x = range(10)
plt.bar(x, top10_gdppercapita.gdpPerCapita / 1000)
plt.xticks(x, top10_gdppercapita.country, rotation='vertical')
plt.title('10 Countries with Highest GDP per Capita in 2007')
plt.ylabel('GDP per Capita 1000USD pp')
plt.show();

# %% [markdown]
# ## What's the fastest growing country in GDP?

# %%
group_by_country = data.groupby(['country'])
#group_by_country['gdp'] = group_by_country.gdpPerCapita * group_by_country.population

#group_by_country = data.groupby(['country'])
#group_by_country.['gdpPe'].pct_change() + 1
group_by_country.head()
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 0            Afghanistan      Asia  1952          28.801     8425333
# 1            Afghanistan      Asia  1957          30.332     9240934
# 2            Afghanistan      Asia  1962          31.997    10267083
# 3            Afghanistan      Asia  1967          34.020    11537966
# 4            Afghanistan      Asia  1972          36.088    13079460
# 12               Albania    Europe  1952          55.230     1282697
# 13               Albania    Europe  1957          59.280     1476505
# 14               Albania    Europe  1962          64.820     1728137
# 15               Albania    Europe  1967          66.220     1984060
# 16               Albania    Europe  1972          67.690     2263554
# 24               Algeria    Africa  1952          43.077     9279525
# 25               Algeria    Africa  1957          45.685    10270856
# 26               Algeria    Africa  1962          48.303    11000948
# 27               Algeria    Africa  1967          51.407    12760499
# 28               Algeria    Africa  1972          54.518    14760787
# 36                Angola    Africa  1952          30.015     4232095
# 37                Angola    Africa  1957          31.999     4561361
# 38                Angola    Africa  1962          34.000     4826015
# 39                Angola    Africa  1967          35.985     5247469
# 40                Angola    Africa  1972          37.928     5894858
# 48             Argentina  Americas  1952          62.485    17876956
# 49             Argentina  Americas  1957          64.399    19610538
# 50             Argentina  Americas  1962          65.142    21283783
# 51             Argentina  Americas  1967          65.634    22934225
# 52             Argentina  Americas  1972          67.065    24779799
# 60             Australia   Oceania  1952          69.120     8691212
# 61             Australia   Oceania  1957          70.330     9712569
# 62             Australia   Oceania  1962          70.930    10794968
# 63             Australia   Oceania  1967          71.100    11872264
# 64             Australia   Oceania  1972          71.930    13177000
# ...                  ...       ...   ...             ...         ...
# 1632           Venezuela  Americas  1952          55.088     5439568
# 1633           Venezuela  Americas  1957          57.907     6702668
# 1634           Venezuela  Americas  1962          60.770     8143375
# 1635           Venezuela  Americas  1967          63.479     9709552
# 1636           Venezuela  Americas  1972          65.712    11515649
# 1644             Vietnam      Asia  1952          40.412    26246839
# 1645             Vietnam      Asia  1957          42.887    28998543
# 1646             Vietnam      Asia  1962          45.363    33796140
# 1647             Vietnam      Asia  1967          47.838    39463910
# 1648             Vietnam      Asia  1972          50.254    44655014
# 1656  West Bank and Gaza      Asia  1952          43.160     1030585
# 1657  West Bank and Gaza      Asia  1957          45.671     1070439
# 1658  West Bank and Gaza      Asia  1962          48.127     1133134
# 1659  West Bank and Gaza      Asia  1967          51.631     1142636
# 1660  West Bank and Gaza      Asia  1972          56.532     1089572
# 1668         Yemen, Rep.      Asia  1952          32.548     4963829
# 1669         Yemen, Rep.      Asia  1957          33.970     5498090
# 1670         Yemen, Rep.      Asia  1962          35.180     6120081
# 1671         Yemen, Rep.      Asia  1967          36.984     6740785
# 1672         Yemen, Rep.      Asia  1972          39.848     7407075
# 1680              Zambia    Africa  1952          42.038     2672000
# 1681              Zambia    Africa  1957          44.077     3016000
# 1682              Zambia    Africa  1962          46.023     3421000
# 1683              Zambia    Africa  1967          47.768     3900000
# 1684              Zambia    Africa  1972          50.107     4506497
# 1692            Zimbabwe    Africa  1952          48.451     3080907
# 1693            Zimbabwe    Africa  1957          50.469     3646340
# 1694            Zimbabwe    Africa  1962          52.358     4277736
# 1695            Zimbabwe    Africa  1967          53.995     4995432
# 1696            Zimbabwe    Africa  1972          55.635     5861135
#
#       gdpPerCapita
# 0       779.445314
# 1       820.853030
# 2       853.100710
# 3       836.197138
# 4       739.981106
# 12     1601.056136
# 13     1942.284244
# 14     2312.888958
# 15     2760.196931
# 16     3313.422188
# 24     2449.008185
# 25     3013.976023
# 26     2550.816880
# 27     3246.991771
# 28     4182.663766
# 36     3520.610273
# 37     3827.940465
# 38     4269.276742
# 39     5522.776375
# 40     5473.288005
# 48     5911.315053
# 49     6856.856212
# 50     7133.166023
# 51     8052.953021
# 52     9443.038526
# 60    10039.595640
# 61    10949.649590
# 62    12217.226860
# 63    14526.124650
# 64    16788.629480
# ...            ...
# 1632   7689.799761
# 1633   9802.466526
# 1634   8422.974165
# 1635   9541.474188
# 1636  10505.259660
# 1644    605.066492
# 1645    676.285448
# 1646    772.049160
# 1647    637.123289
# 1648    699.501644
# 1656   1515.592329
# 1657   1827.067742
# 1658   2198.956312
# 1659   2649.715007
# 1660   3133.409277
# 1668    781.717576
# 1669    804.830455
# 1670    825.623201
# 1671    862.442146
# 1672   1265.047031
# 1680   1147.388831
# 1681   1311.956766
# 1682   1452.725766
# 1683   1777.077318
# 1684   1773.498265
# 1692    406.884115
# 1693    518.764268
# 1694    527.272182
# 1695    569.795071
# 1696    799.362176
#
# [710 rows x 6 columns]

# %% [markdown]
# ## Which country resembles the U.S. the most?

# %% [markdown]
# ## How is population related to GDP per capita?
