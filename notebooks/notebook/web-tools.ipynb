# %%
import jwt
import json
import demjson
import barely_json
from IPython.display import display, JSON, Markdown

# %% [markdown]
# # Web Tools
#
# #### Contents
# - [JWT Decoder](#jwtdecoder)
# - [JSON Tools](#json)

# %% [markdown]
# ----
#
# ## <a name="jwtdecoder"></a>JWT Decoder
#
# #### Resources
# - [PyJWT docs](https://pyjwt.readthedocs.io/en/latest/)

# %%
# Decode JWT Claimset

encoded_jwt = ''
secret = ''
verify = False

# Perform decoding
jwt_obj = jwt.decode(encoded_jwt, secret, algorithms=['HS256'], verify=verify)
display(Markdown("#### JSON"))
display(JSON(jwt_obj))
display(Markdown("----\n#### Raw"))
display(jwt_obj)

# %% [markdown]
# ----
#
# ## <a name="json"></a>JSON Tools
#
# #### Resources
# - [demjson](https://github.com/dmeranda/demjson)
# - [Barely JSON](https://github.com/torfsen/barely_json)

# %%
json_str = """[{
    "id": "sx2vnh",
    "facebookId": "105872999557408",
    "name": "brighteroptionselenium2@gmail.com",
    "currencyCode": "USD",
    "pages": [{
      "facebookId": "436906149727519",
      "name": "Selenium Guru",
      "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
    }]
  },
  {
    "id": "sx21a3",
    "facebookId": "1088176427933818",
    "name": "Advertising Studio - Phoenix - JBA - USD",
    "currencyCode": "USD",
    "pages": [{
        "facebookId": "103843730069886",
        "name": "Advertising Studio - JBA 5",
        "imageUrl": "https://graph.facebook.com/103843730069886/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "196168440408363",
        "name": "Demo",
        "imageUrl": "https://graph.facebook.com/196168440408363/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "403399859695864",
        "name": "Brighter Option",
        "imageUrl": "https://graph.facebook.com/403399859695864/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "436906149727519",
        "name": "Selenium Guru",
        "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "593803337465501",
        "name": "Closer",
        "imageUrl": "https://graph.facebook.com/593803337465501/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1044401422344264",
        "name": "Advertising Studio - JBA 4",
        "imageUrl": "https://graph.facebook.com/1044401422344264/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1063154647067022",
        "name": "Advertising Studio - JBA 2",
        "imageUrl": "https://graph.facebook.com/1063154647067022/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1223844307665597",
        "name": "Advertising Studio",
        "imageUrl": "https://graph.facebook.com/1223844307665597/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1570081483300684",
        "name": "Advertising Studio - JBA 3",
        "imageUrl": "https://graph.facebook.com/1570081483300684/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1633047743652400",
        "name": "Advertising Studio - JBA 1",
        "imageUrl": "https://graph.facebook.com/1633047743652400/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1768910733388490",
        "name": "Advertising Studio - JBA",
        "imageUrl": "https://graph.facebook.com/1768910733388490/picture?type=square&return_ssl_resources=1"
      }
    ]
  },
  {
    "id": "sx21a6",
    "facebookId": "1240162119401914",
    "name": "Advertising Studio - Phoenix - JBA 2 - USD",
    "currencyCode": "USD",
    "pages": [{
        "facebookId": "103843730069886",
        "name": "Advertising Studio - JBA 5",
        "imageUrl": "https://graph.facebook.com/103843730069886/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1044401422344264",
        "name": "Advertising Studio - JBA 4",
        "imageUrl": "https://graph.facebook.com/1044401422344264/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1063154647067022",
        "name": "Advertising Studio - JBA 2",
        "imageUrl": "https://graph.facebook.com/1063154647067022/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1570081483300684",
        "name": "Advertising Studio - JBA 3",
        "imageUrl": "https://graph.facebook.com/1570081483300684/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1633047743652400",
        "name": "Advertising Studio - JBA 1",
        "imageUrl": "https://graph.facebook.com/1633047743652400/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1768910733388490",
        "name": "Advertising Studio - JBA",
        "imageUrl": "https://graph.facebook.com/1768910733388490/picture?type=square&return_ssl_resources=1"
      }
    ]
  },
  {
    "id": "sx21bd",
    "facebookId": "1322887111129414",
    "name": "Advertising Studio - Phoenix - JBA 3 - USD",
    "currencyCode": "USD",
    "pages": [{
        "facebookId": "103843730069886",
        "name": "Advertising Studio - JBA 5",
        "imageUrl": "https://graph.facebook.com/103843730069886/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "196168440408363",
        "name": "Demo",
        "imageUrl": "https://graph.facebook.com/196168440408363/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "403399859695864",
        "name": "Brighter Option",
        "imageUrl": "https://graph.facebook.com/403399859695864/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "436906149727519",
        "name": "Selenium Guru",
        "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "593803337465501",
        "name": "Closer",
        "imageUrl": "https://graph.facebook.com/593803337465501/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1044401422344264",
        "name": "Advertising Studio - JBA 4",
        "imageUrl": "https://graph.facebook.com/1044401422344264/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1063154647067022",
        "name": "Advertising Studio - JBA 2",
        "imageUrl": "https://graph.facebook.com/1063154647067022/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1223844307665597",
        "name": "Advertising Studio",
        "imageUrl": "https://graph.facebook.com/1223844307665597/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1545682998844455",
        "name": "Mural",
        "imageUrl": "https://graph.facebook.com/1545682998844455/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1570081483300684",
        "name": "Advertising Studio - JBA 3",
        "imageUrl": "https://graph.facebook.com/1570081483300684/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1607573216232294",
        "name": "Social.com London",
        "imageUrl": "https://graph.facebook.com/1607573216232294/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1633047743652400",
        "name": "Advertising Studio - JBA 1",
        "imageUrl": "https://graph.facebook.com/1633047743652400/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1768910733388490",
        "name": "Advertising Studio - JBA",
        "imageUrl": "https://graph.facebook.com/1768910733388490/picture?type=square&return_ssl_resources=1"
      }
    ]
  },
  {
    "id": "sx20ig",
    "facebookId": "1456017491149708",
    "name": "Advertising Studio - Phoenix - JBA - EUR",
    "currencyCode": "EUR",
    "pages": [{
        "facebookId": "103843730069886",
        "name": "Advertising Studio - JBA 5",
        "imageUrl": "https://graph.facebook.com/103843730069886/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "196168440408363",
        "name": "Demo",
        "imageUrl": "https://graph.facebook.com/196168440408363/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "403399859695864",
        "name": "Brighter Option",
        "imageUrl": "https://graph.facebook.com/403399859695864/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "436906149727519",
        "name": "Selenium Guru",
        "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "593803337465501",
        "name": "Closer",
        "imageUrl": "https://graph.facebook.com/593803337465501/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1044401422344264",
        "name": "Advertising Studio - JBA 4",
        "imageUrl": "https://graph.facebook.com/1044401422344264/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1063154647067022",
        "name": "Advertising Studio - JBA 2",
        "imageUrl": "https://graph.facebook.com/1063154647067022/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1223844307665597",
        "name": "Advertising Studio",
        "imageUrl": "https://graph.facebook.com/1223844307665597/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1545682998844455",
        "name": "Mural",
        "imageUrl": "https://graph.facebook.com/1545682998844455/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1570081483300684",
        "name": "Advertising Studio - JBA 3",
        "imageUrl": "https://graph.facebook.com/1570081483300684/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1607573216232294",
        "name": "Social.com London",
        "imageUrl": "https://graph.facebook.com/1607573216232294/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1633047743652400",
        "name": "Advertising Studio - JBA 1",
        "imageUrl": "https://graph.facebook.com/1633047743652400/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1768910733388490",
        "name": "Advertising Studio - JBA",
        "imageUrl": "https://graph.facebook.com/1768910733388490/picture?type=square&return_ssl_resources=1"
      }
    ]
  },
  {
    "id": "sx20ij",
    "facebookId": "1456018627816261",
    "name": "Advertising Studio - Phoenix - JBA - CAD",
    "currencyCode": "CAD",
    "pages": [{
        "facebookId": "103843730069886",
        "name": "Advertising Studio - JBA 5",
        "imageUrl": "https://graph.facebook.com/103843730069886/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "196168440408363",
        "name": "Demo",
        "imageUrl": "https://graph.facebook.com/196168440408363/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "403399859695864",
        "name": "Brighter Option",
        "imageUrl": "https://graph.facebook.com/403399859695864/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "436906149727519",
        "name": "Selenium Guru",
        "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "593803337465501",
        "name": "Closer",
        "imageUrl": "https://graph.facebook.com/593803337465501/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1044401422344264",
        "name": "Advertising Studio - JBA 4",
        "imageUrl": "https://graph.facebook.com/1044401422344264/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1063154647067022",
        "name": "Advertising Studio - JBA 2",
        "imageUrl": "https://graph.facebook.com/1063154647067022/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1223844307665597",
        "name": "Advertising Studio",
        "imageUrl": "https://graph.facebook.com/1223844307665597/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1545682998844455",
        "name": "Mural",
        "imageUrl": "https://graph.facebook.com/1545682998844455/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1570081483300684",
        "name": "Advertising Studio - JBA 3",
        "imageUrl": "https://graph.facebook.com/1570081483300684/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1607573216232294",
        "name": "Social.com London",
        "imageUrl": "https://graph.facebook.com/1607573216232294/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1633047743652400",
        "name": "Advertising Studio - JBA 1",
        "imageUrl": "https://graph.facebook.com/1633047743652400/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1768910733388490",
        "name": "Advertising Studio - JBA",
        "imageUrl": "https://graph.facebook.com/1768910733388490/picture?type=square&return_ssl_resources=1"
      }
    ]
  },
  {
    "id": "sx20ii",
    "facebookId": "1456018174482973",
    "name": "Advertising Studio - Phoenix - JBA - AUD",
    "currencyCode": "AUD",
    "pages": [{
        "facebookId": "103843730069886",
        "name": "Advertising Studio - JBA 5",
        "imageUrl": "https://graph.facebook.com/103843730069886/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "196168440408363",
        "name": "Demo",
        "imageUrl": "https://graph.facebook.com/196168440408363/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "403399859695864",
        "name": "Brighter Option",
        "imageUrl": "https://graph.facebook.com/403399859695864/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "436906149727519",
        "name": "Selenium Guru",
        "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "593803337465501",
        "name": "Closer",
        "imageUrl": "https://graph.facebook.com/593803337465501/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1044401422344264",
        "name": "Advertising Studio - JBA 4",
        "imageUrl": "https://graph.facebook.com/1044401422344264/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1063154647067022",
        "name": "Advertising Studio - JBA 2",
        "imageUrl": "https://graph.facebook.com/1063154647067022/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1223844307665597",
        "name": "Advertising Studio",
        "imageUrl": "https://graph.facebook.com/1223844307665597/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1545682998844455",
        "name": "Mural",
        "imageUrl": "https://graph.facebook.com/1545682998844455/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1570081483300684",
        "name": "Advertising Studio - JBA 3",
        "imageUrl": "https://graph.facebook.com/1570081483300684/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1607573216232294",
        "name": "Social.com London",
        "imageUrl": "https://graph.facebook.com/1607573216232294/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1633047743652400",
        "name": "Advertising Studio - JBA 1",
        "imageUrl": "https://graph.facebook.com/1633047743652400/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1768910733388490",
        "name": "Advertising Studio - JBA",
        "imageUrl": "https://graph.facebook.com/1768910733388490/picture?type=square&return_ssl_resources=1"
      }
    ]
  },
  {
    "id": "sx20il",
    "facebookId": "1456023277815796",
    "name": "Advertising Studio - Phoenix - JBA - GBP 1",
    "currencyCode": "GBP",
    "pages": [{
        "facebookId": "103843730069886",
        "name": "Advertising Studio - JBA 5",
        "imageUrl": "https://graph.facebook.com/103843730069886/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "196168440408363",
        "name": "Demo",
        "imageUrl": "https://graph.facebook.com/196168440408363/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "403399859695864",
        "name": "Brighter Option",
        "imageUrl": "https://graph.facebook.com/403399859695864/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "436906149727519",
        "name": "Selenium Guru",
        "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "593803337465501",
        "name": "Closer",
        "imageUrl": "https://graph.facebook.com/593803337465501/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1044401422344264",
        "name": "Advertising Studio - JBA 4",
        "imageUrl": "https://graph.facebook.com/1044401422344264/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1063154647067022",
        "name": "Advertising Studio - JBA 2",
        "imageUrl": "https://graph.facebook.com/1063154647067022/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1223844307665597",
        "name": "Advertising Studio",
        "imageUrl": "https://graph.facebook.com/1223844307665597/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1545682998844455",
        "name": "Mural",
        "imageUrl": "https://graph.facebook.com/1545682998844455/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1570081483300684",
        "name": "Advertising Studio - JBA 3",
        "imageUrl": "https://graph.facebook.com/1570081483300684/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1607573216232294",
        "name": "Social.com London",
        "imageUrl": "https://graph.facebook.com/1607573216232294/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1633047743652400",
        "name": "Advertising Studio - JBA 1",
        "imageUrl": "https://graph.facebook.com/1633047743652400/picture?type=square&return_ssl_resources=1"
      },
      {
        "facebookId": "1768910733388490",
        "name": "Advertising Studio - JBA",
        "imageUrl": "https://graph.facebook.com/1768910733388490/picture?type=square&return_ssl_resources=1"
      }
    ]
  },
  {
    "id": "sx20iw",
    "facebookId": "818132058271591",
    "name": "Regression week",
    "currencyCode": "GBP",
    "pages": [{
      "facebookId": "436906149727519",
      "name": "Selenium Guru",
      "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
    }]
  },
  {
    "id": "sx20iz",
    "facebookId": "911541752263954",
    "name": "Social.Com Team Thundercats Integration (USD)",
    "currencyCode": "USD",
    "pages": []
  },
  {
    "id": "sx20iy",
    "facebookId": "716827961735335",
    "name": "The Cheese Machine Mock Account",
    "currencyCode": "USD",
    "pages": []
  },
  {
    "id": "sx20lh",
    "facebookId": "706023069482491",
    "name": "Social.com Test 1",
    "currencyCode": "GBP",
    "pages": [{
      "facebookId": "436906149727519",
      "name": "Selenium Guru",
      "imageUrl": "https://graph.facebook.com/436906149727519/picture?type=square&return_ssl_resources=1"
    }]
  },
  {
    "id": "sx20kb",
    "facebookId": "716827018402096",
    "name": "Selenium Guru Mock Account",
    "currencyCode": "USD",
    "pages": []
  },
  {
    "id": "sx20kd",
    "facebookId": "779696288781835",
    "name": "Social.com Sydney Time Account (USD)",
    "currencyCode": "USD",
    "pages": []
  }
]"""

# %%
# json

obj = json.loads(json_str)
display(Markdown("#### JSON"))
display(JSON(obj))
display(Markdown("----\n#### Formatted"))
display(Markdown('```json\n' + json_str + '```'))
display(Markdown("----\n#### Raw"))
display(json_str)

# %%
# demjson
obj = demjson.decode(json_str)[0]
display(Markdown("#### JSON"))
display(JSON(obj))
display(Markdown("----\n#### Formatted"))
display(Markdown('```json\n' + json_str + '```'))
display(Markdown("----\n#### Raw"))
display(json_str)

# %%
# barely_json
obj = barely_json.parse(json_str)[0]
display(Markdown("#### JSON"))
display(JSON(obj))
display(Markdown("----\n#### Formatted"))
display(Markdown('```json\n' + json_str + '```'))
display(Markdown("----\n#### Raw"))
display(json_str)

# %% [markdown]
# -----
