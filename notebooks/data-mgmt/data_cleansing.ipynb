# %% [markdown]
# # Data Cleansing
#
# 1. Disconnected Data
# - Different file formats
# - Locations
# - Databases
#
# Solve by identifying and moving data to desired place. Filtering.
# Connecting/matching records/data when possible.
#
# 2.
# - Duplicate data
# - Stale Data
# - Ambiguous Data
#   - e.g. peoples names as an identifier
# - Incorrect Data
# - Missing Data
# - Normalizing measurements i.e metrics
# - Identifying & correcting equivalent values i.e. different enumerations/ranges
# - Translating Texts
# - Delocalizing formats such as numbers, addresses, dates, phone numbers etc
# - Spelling Mistakes
#   - if data retrieve by phone we can use audible distance
#   - if typed, use something like type distance
#
# Example - Names
#     G. Jones
#     Greg Jones
#     Gregory J
#     Greg Thomas Jones
#     Greg T. Jownes
#     names can change (i.e. deed poll, marriage)
#
# Phone
#     People can have multiple phone numbers
#     People can write their phone nnumber in many ways
#
# Addresses
#     Addresses can have multiple phone numbers
#     Addresses can write their phone nnumber in many ways
#
# |Action|Time Spent(%)|
# |-|-|
# |Cleaning & Organizing Data| 60%|
# |Collecting Datasets|19%|
# |Mining for Patterns|9%|
# |Other|5%|
# |Refining Algorithms|4%|
# |Building Training Sets|3%|
#
#
#
# ## Solving Disconnected Data
#
# - Record Linkage
# - Data Matching
# - Object Identity Problem
# - Deduplication
# - Record Matching
# - Entity Linking
# - Duplicate Delction
# - Coreference Resolution
# - Entity Resolution
# - Identity Resolution
# - Name Resolution
# - Entity Disambguation
# - Object Identification
# - Merge/Purge Processing
# - List Washing
# - Conflation
# - Data Integration
# - Information Integration
# - Reference Reconciliation
#
# ## Phonetic Algorithms
#
# SoundX - resolves minor spelling differences
#  - "Grig" -> G620
#  - "Greg" -> G620
#
# Knowledge-based approach can help associate equivlant spellings
#  - "Greg" $\equiv$ "Gregory"
#
# Edit Distance
#  - Spelling mistakes - common for addresses and names
#
# Better to get verified and vetted data from a trusted source
#
# when matching data, consider the purpose.
#
# perhaps there are big consequences for people if they were incorrectly matched. i.e. Credit checking companies, and bad credit incorrectly linked to person of a similar name, address etc
#
# ----
#
#
#
# ----
#
# ## References
#
# - [Solving Disconnected Data: Getting to Actionable Insights with Keying and Linking][1]
#
#  [1]: https://www.youtube.com/watch?v=u4Bf4DMEhj0&list=LLonVfxXodg78Tzh5nNu85Ew&index=1
